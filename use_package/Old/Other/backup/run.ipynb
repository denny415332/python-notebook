# %%
from src.measure import measure

# TEST_CFG_PATH = "./config/WAVE174389_LED_flex_100%_duty_test_params.json"
TEST_CFG_PATH = "./config/test_config.json"
CALIBRATION_PATH = "./config/OCCELOT_V1_cal_led_flex_B4_50um-2024-11-25 113545.csv"
SERIAL_NUMBER = "WAVE174467"
OPERATOR_NUMBER = "111"

measure(TEST_CFG_PATH, CALIBRATION_PATH, SERIAL_NUMBER, OPERATOR_NUMBER)
print("finish")
# Out:
# LedCurrent(red=150.10163413130437, green=2.8647326123954864, blue=2.8647326123954864, green2=0.0)
# Fetching Spectrum
# max intensity: 64478.29, integration time: 30000.0 µs
# max intensity: 51016.00, integration time: 23728 µs
# max intensities: 51015.9979989
# Adjusted integration time: 0.023728s
# Fetching Dark Spectrum
# Fetching Spectrum
# Calibrate Spectrum
# c:\Users\op.yo\Desktop\workspace\repo\YL_13-gen2\src\measure.py:123: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   fig.legend()
# LedCurrent(red=2.8647326123954864, green=150.10163413130437, blue=2.8647326123954864, green2=0.0)
# Fetching Spectrum
# max intensity: 30726.08, integration time: 30000.0 µs
# max intensity: 51020.37, integration time: 49794 µs
# max intensities: 51020.3712296
# Adjusted integration time: 0.049794s
# Fetching Dark Spectrum
# Fetching Spectrum
# Calibrate Spectrum
# ...
